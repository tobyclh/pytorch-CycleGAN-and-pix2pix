# %%
import os
from options.test_options import TestOptions
from data import CreateDataLoader
from models import create_model
from util.visualizer import Visualizer
from util import html
import torch
from models.cycle_gan_model import CycleGANModel
import matplotlib.pyplot as plt

# %%
opt = TestOptions().parse()
opt.dataroot = 'datasets/horse2zebra/testA'
opt.checkpoints_dir = './checkpoints/'
opt.name = 'horse2zebra_pretrained'
opt.no_dropout = True
opt.model = 'test'
opt.dataset_mode = 'single'
opt.loadSize = 256
opt.nThreads = 1   # test code only supports nThreads = 1
opt.batchSize = 1  # test code only supports batchSize = 1
opt.serial_batches = True  # no shuffle
opt.no_flip = True  # no flip
opt.display_id = -1  # no visdom display
opt.which_model_netG = 'unet_256'
data_loader = CreateDataLoader(opt)
dataset = data_loader.load_data()
model = create_model(opt)
# Out:
# ------------ Options -------------
# aspect_ratio: 1.0
# batchSize: 1
# checkpoints_dir: ./checkpoints
# dataroot: None
# dataset_mode: unaligned
# display_id: 1
# display_port: 8097
# display_server: http://localhost
# display_winsize: 256
# fineSize: 256
# gpu_ids: [0]
# how_many: 50
# init_type: normal
# input_nc: 3
# isTrain: False
# loadSize: 286
# max_dataset_size: inf
# model: cycle_gan
# nThreads: 4
# n_layers_D: 3
# name: experiment_name
# ndf: 64
# ngf: 64
# no_dropout: False
# no_flip: False
# norm: instance
# ntest: inf
# output_nc: 3
# phase: test
# resize_or_crop: resize_and_crop
# results_dir: ./results/
# serial_batches: False
# suffix:
# verbose: False
# which_direction: AtoB
# which_epoch: latest
# which_model_netD: basic
# which_model_netG: resnet_9blocks
# -------------- End ----------------
# CustomDatasetDataLoader
# dataset [SingleImageDataset] was created
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 54.410 M
# -----------------------------------------------
# model [TestModel] was created

# %%
data_iter = iter(data_loader)
data = next(data_iter)
result = model.netG(data['A'],cache=True)
# Out:
# Forwarding : x torch.Size([1, 3, 256, 256])
# intermediate : torch.Size([1, 512, 1, 1])
# isOutermost
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-3-f7808e56803c> in <module>()
#       1 data_iter = iter(data_loader)
#       2 data = next(data_iter)
# ----> 3 result = model.netG(data['A'],cache=True)
#
# ~/anaconda3/envs/exp/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     369             result = self._slow_forward(*input, **kwargs)
#     370         else:
# --> 371             result = self.forward(*input, **kwargs)
#     372         for hook in self._forward_hooks.values():
#     373             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/exp/lib/python3.6/site-packages/torch/nn/parallel/data_parallel.py in forward(self, *inputs, **kwargs)
#      96         inputs, kwargs = self.scatter(inputs, kwargs, self.device_ids)
#      97         if len(self.device_ids) == 1:
# ---> 98             return self.module(*inputs[0], **kwargs[0])
#      99         replicas = self.replicate(self.module, self.device_ids[:len(inputs)])
#     100         outputs = self.parallel_apply(replicas, inputs, kwargs)
#
# ~/anaconda3/envs/exp/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     369             result = self._slow_forward(*input, **kwargs)
#     370         else:
# --> 371             result = self.forward(*input, **kwargs)
#     372         for hook in self._forward_hooks.values():
#     373             hook_result = hook(self, input, result)
#
# ~/Documents/pytorch-CycleGAN-and-pix2pix/models/networks.py in forward(self, input, full, cache)
#     273     def forward(self, input, full=True, cache=False):
#     274         if full:
# --> 275             return self.model(input,cache=cache)
#     276         else:
#     277             return self.model.half_forward(input)
#
# ~/anaconda3/envs/exp/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     369             result = self._slow_forward(*input, **kwargs)
#     370         else:
# --> 371             result = self.forward(*input, **kwargs)
#     372         for hook in self._forward_hooks.values():
#     373             hook_result = hook(self, input, result)
#
# ~/Documents/pytorch-CycleGAN-and-pix2pix/models/networks.py in forward(self, x, cache)
#     339         if self.outermost:
#     340             print('isOutermost')
# --> 341             return self.up(x)
#     342         else:
#     343             print('not Outermost')
#
# ~/anaconda3/envs/exp/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     369             result = self._slow_forward(*input, **kwargs)
#     370         else:
# --> 371             result = self.forward(*input, **kwargs)
#     372         for hook in self._forward_hooks.values():
#     373             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/exp/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      89     def forward(self, input):
#      90         for module in self._modules.values():
# ---> 91             input = module(input)
#      92         return input
#      93
#
# ~/anaconda3/envs/exp/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     369             result = self._slow_forward(*input, **kwargs)
#     370         else:
# --> 371             result = self.forward(*input, **kwargs)
#     372         for hook in self._forward_hooks.values():
#     373             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/exp/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      89     def forward(self, input):
#      90         for module in self._modules.values():
# ---> 91             input = module(input)
#      92         return input
#      93
#
# ~/anaconda3/envs/exp/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     369             result = self._slow_forward(*input, **kwargs)
#     370         else:
# --> 371             result = self.forward(*input, **kwargs)
#     372         for hook in self._forward_hooks.values():
#     373             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/exp/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      89     def forward(self, input):
#      90         for module in self._modules.values():
# ---> 91             input = module(input)
#      92         return input
#      93
#
# ~/anaconda3/envs/exp/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     369             result = self._slow_forward(*input, **kwargs)
#     370         else:
# --> 371             result = self.forward(*input, **kwargs)
#     372         for hook in self._forward_hooks.values():
#     373             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/exp/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      89     def forward(self, input):
#      90         for module in self._modules.values():
# ---> 91             input = module(input)
#      92         return input
#      93
#
# ~/anaconda3/envs/exp/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     369             result = self._slow_forward(*input, **kwargs)
#     370         else:
# --> 371             result = self.forward(*input, **kwargs)
#     372         for hook in self._forward_hooks.values():
#     373             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/exp/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      89     def forward(self, input):
#      90         for module in self._modules.values():
# ---> 91             input = module(input)
#      92         return input
#      93
#
# ~/anaconda3/envs/exp/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     369             result = self._slow_forward(*input, **kwargs)
#     370         else:
# --> 371             result = self.forward(*input, **kwargs)
#     372         for hook in self._forward_hooks.values():
#     373             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/exp/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      89     def forward(self, input):
#      90         for module in self._modules.values():
# ---> 91             input = module(input)
#      92         return input
#      93
#
# ~/anaconda3/envs/exp/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     369             result = self._slow_forward(*input, **kwargs)
#     370         else:
# --> 371             result = self.forward(*input, **kwargs)
#     372         for hook in self._forward_hooks.values():
#     373             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/exp/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      89     def forward(self, input):
#      90         for module in self._modules.values():
# ---> 91             input = module(input)
#      92         return input
#      93
#
# ~/anaconda3/envs/exp/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     369             result = self._slow_forward(*input, **kwargs)
#     370         else:
# --> 371             result = self.forward(*input, **kwargs)
#     372         for hook in self._forward_hooks.values():
#     373             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/exp/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      89     def forward(self, input):
#      90         for module in self._modules.values():
# ---> 91             input = module(input)
#      92         return input
#      93
#
# ~/anaconda3/envs/exp/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     369             result = self._slow_forward(*input, **kwargs)
#     370         else:
# --> 371             result = self.forward(*input, **kwargs)
#     372         for hook in self._forward_hooks.values():
#     373             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/exp/lib/python3.6/site-packages/torch/nn/modules/conv.py in forward(self, input, output_size)
#     661         return F.conv_transpose2d(
#     662             input, self.weight, self.bias, self.stride, self.padding,
# --> 663             output_padding, self.groups, self.dilation)
#     664
#     665
#
# RuntimeError: Given transposed=1, weight[512, 512, 4, 4], so expected input[1, 3, 256, 256] to have 512 channels, but got 3 channels instead
